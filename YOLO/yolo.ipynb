# %% [markdown]
# `63070501061 S.RAKNA`
#
# > 20 points, 1 hr.
#
# # YOLO (You Only Look Once)
#
# - Use the Yolo colab on your own image you took and a video you took.
# - In each at least 3 objects should be visible. Were they detected?

# %%
import os

import matplotlib.pyplot as plt
from imageai.Detection import ObjectDetection, VideoObjectDetection

# %%
# !ls './data/'
# Out:
# friend.MOV       sleep_output.png yolov3.pt
# sleep.png        yolo.h5

# %%
# Detect Objects From Images

# Test images
# for more details imageai manual: https://imageai.readthedocs.io/en/latest/
execution_path = './data/'
detector = ObjectDetection()
detector.setModelTypeAsYOLOv3()
# Uses pretrained models trained on the COCO dataset
detector.setModelPath(os.path.join(execution_path, "yolov3.pt"))
detector.loadModel()
input_file = os.path.join(execution_path, "sleep.png")
output_file = os.path.join(execution_path, "sleep_output.png")
detections = detector.detectObjectsFromImage(
    input_image=input_file,
    output_image_path=output_file,
    minimum_percentage_probability=30
)

# %%
# Show the image with the objects identified

plt.figure(figsize=(20, 20))
plt.imshow(plt.imread(output_file))
plt.show()

# %%
# Detect Objects From Video

# Test videos
execution_path = './data/'
detector = VideoObjectDetection()
detector.setModelTypeAsYOLOv3()
# Uses pretrained models trained on the COCO dataset
detector.setModelPath(os.path.join(execution_path, "yolov3.pt"))
detector.loadModel()
input_file = os.path.join(execution_path, "friend.MOV")
output_file = os.path.join(execution_path, "friend_output")
video_path = detector.detectObjectsFromVideo(
    input_file_path=input_file,
    output_file_path=output_file,
    frames_per_second=60, log_progress=True
)
# Out:
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# Processing Frame :  1
# Processing Frame :  2
# Processing Frame :  3
# Processing Frame :  4
# Processing Frame :  5
# Processing Frame :  6
# Processing Frame :  7
# Processing Frame :  8
# Processing Frame :  9
# Processing Frame :  10
# Processing Frame :  11
# Processing Frame :  12
# Processing Frame :  13
# Processing Frame :  14
# Processing Frame :  15
# Processing Frame :  16
# Processing Frame :  17
# Processing Frame :  18
# Processing Frame :  19
# Processing Frame :  20
# Processing Frame :  21
# Processing Frame :  22
# Processing Frame :  23
# Processing Frame :  24
# Processing Frame :  25
# Processing Frame :  26
# Processing Frame :  27
# Processing Frame :  28
# Processing Frame :  29
# Processing Frame :  30
# Processing Frame :  31
# Processing Frame :  32
# Processing Frame :  33
# ...

# %%
# !ls './data/'
# Out:
# friend.MOV        sleep.png         yolo.h5
# friend_output.mp4 sleep_output.png  yolov3.pt

# %% [markdown]
# <a style="font-size:18px" href="https://youtube.com/shorts/bu8XsKd66Sg?feature=share">Output Video Link.</a>
